# %% [markdown]
# ## Завдання 1
#
# #### Скільки різних паролів можна скласти, використовуючи три літери англійського алфавіту, якщо літери не повинні повторюватися?

# %% [markdown]
# В англійському алфавіті 26 літер.
# Розміщення однієї і тієї ж літери на різних позиціях для паролю має значення, тому треба тут використати правило "розміщення".
#
# n=26
# r=3
#
# A(26, 3) = 26! / (26-3)! = 26! / 23! = 24 * 25 * 26 = 15 600 --> стільки різних паролів можна скласти із 3х унікальних літер

# %% [markdown]
# ## Завдання 2
#
# #### Є група з 8 людей. Скількома способами можна обрати комітет із 3 осіб?

# %% [markdown]
# Тут неважливий порядок людей, тому треба застосувати правило "сполучення":
#
# n=8
# r=3
#
# C(8, 3) = (8! / (8-3)!) / 3! = 8! / 5! / 3! = (6 * 7 * 8) / (1 * 2 * 3) = 336/6 = 56 способів

# %% [markdown]
# ## Завдання 3
#
# #### Скількома різними способами можна розташувати на полиці 5 різних книг?

# %% [markdown]
# P(5) = 5! = 1 * 2 * 3 * 4 * 5 = 120 способів

# %% [markdown]
# ## Завдання 4
#
# #### В урні знаходяться 4 червоні, 3 сині і 2 зелені кулі. Скількома способами можна витягти 3 кулі, якщо вони повинні бути різних кольорів?

# %% [markdown]
# Нам потрібно витягти і червону, і синю, і зелену кульки, тому використовуємо правило "добутку":
#
# 4 * 3 * 2 = 24 способи
