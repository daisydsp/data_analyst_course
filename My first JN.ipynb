# %% [markdown]
# # My first Jupyter Notebook

# %% [markdown]
# This homework is dedicated to practice working with Jupyter Notebook cells - both Markdowns and Code

# %% [markdown]
# Time spent: **30** **minutes**

# %% [markdown]
# ## Part 1

# %% [markdown]
# Learned and practiced the following hotkeys:
#  - "**a**" (for adding cell above)
#  - "**b**" (for adding cell below)
#  - "**z**" (for cancelling previous action)
#  - "**d-d**" (for deleting a cell)
#  - "**Shift+M**" (for merging cells)
#  - "**Shift+Ctrl+-**" (for splitting cells)
#  - "**Shift+Enter**" (for running the cell)

# %% [markdown]
# ## Part 2

# %%
print("Welcome to Data Analyst Course!")
# Out:
# Welcome to Data Analyst Course!

# %%
a = 15 + 30
b = a / 5
c = (a + b)**2

print(c)
# Out:
# 2916.0

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.sin(range(30)))
